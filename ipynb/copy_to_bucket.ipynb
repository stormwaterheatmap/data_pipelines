# %%
from google.cloud import storage
import os
# Out:
# /Users/christiannilsen/.local/share/virtualenvs/data_pipelines-nRJIciM3/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
from google.cloud import storage


def copy_blob(
    bucket_name, blob_name, destination_bucket_name, destination_blob_name,
):
    """Copies a blob from one bucket to another with a new name."""
    # bucket_name = "your-bucket-name"
    # blob_name = "your-object-name"
    # destination_bucket_name = "destination-bucket-name"
    # destination_blob_name = "destination-object-name"

    storage_client = storage.Client()

    source_bucket = storage_client.bucket(bucket_name)
    source_blob = source_bucket.blob(blob_name)
    destination_bucket = storage_client.bucket(destination_bucket_name)

    # Optional: set a generation-match precondition to avoid potential race conditions
    # and data corruptions. The request to copy is aborted if the object's
    # generation number does not match your precondition. For a destination
    # object that does not yet exist, set the if_generation_match precondition to 0.
    # If the destination object already exists in your bucket, set instead a
    # generation-match precondition using its generation number.
    # There is also an `if_source_generation_match` parameter, which is not used in this example.
    destination_generation_match_precondition = 0

    blob_copy = source_bucket.copy_blob(
        source_blob, destination_bucket, destination_blob_name, if_generation_match=destination_generation_match_precondition,
    )

    print(
        "Blob {} in bucket {} copied to blob {} in bucket {}.".format(
            source_blob.name,
            source_bucket.name,
            blob_copy.name,
            destination_bucket.name,
        )
    )

# %%
BUCKET_NAME = "live_data_layers"
SRC_PREFIX = "rasters"       # include trailing slash
DEST_PREFIX = "stac/"        # include trailing slash
PROJECT_ID = "swhm-prod"          # or None

# %%
move_assets_one_per_folder(bucket_name=BUCKET_NAME,src_prefix=SRC_PREFIX,dest_prefix=DEST_PREFIX,project=PROJECT_ID)
# Out:
# Copied rasters/Age_of_Imperviousness.tif → stac/Age_of_Imperviousness/Age_of_Imperviousness.tif
# Copied rasters/Age_of_Imperviousness.tif.aux.xml → stac/Age_of_Imperviousness.tif.aux/Age_of_Imperviousness.tif.aux.xml
# Copied rasters/Flow_Duration_Index.tif → stac/Flow_Duration_Index/Flow_Duration_Index.tif
# Copied rasters/Flow_Duration_Index.tif.aux.xml → stac/Flow_Duration_Index.tif.aux/Flow_Duration_Index.tif.aux.xml
# Copied rasters/HSPF_Land_Cover_Type.tif → stac/HSPF_Land_Cover_Type/HSPF_Land_Cover_Type.tif
# Copied rasters/Hydrologic_Response_Units.tif → stac/Hydrologic_Response_Units/Hydrologic_Response_Units.tif
# Copied rasters/Hydrologic_Response_Units.tif.aux.xml → stac/Hydrologic_Response_Units.tif.aux/Hydrologic_Response_Units.tif.aux.xml
# Copied rasters/Imperviousness.tif → stac/Imperviousness/Imperviousness.tif
# Copied rasters/Imperviousness.tif.aux.xml → stac/Imperviousness.tif.aux/Imperviousness.tif.aux.xml
# Copied rasters/Land_Cover.tif → stac/Land_Cover/Land_Cover.tif
# Copied rasters/Land_Cover_rio.tif.aux.xml → stac/Land_Cover_rio.tif.aux/Land_Cover_rio.tif.aux.xml
# Copied rasters/Land_Use.tif → stac/Land_Use/Land_Use.tif
# Copied rasters/Land_Use_rio.tif.aux.xml → stac/Land_Use_rio.tif.aux/Land_Use_rio.tif.aux.xml
# Copied rasters/Population_Density.tif → stac/Population_Density/Population_Density.tif
# Copied rasters/Population_Density.tif.aux.xml → stac/Population_Density.tif.aux/Population_Density.tif.aux.xml
# Copied rasters/Precipitation_mm.tif → stac/Precipitation_mm/Precipitation_mm.tif
# Copied rasters/Precipitation_mm.tif.aux.xml → stac/Precipitation_mm.tif.aux/Precipitation_mm.tif.aux.xml
# Copied rasters/Runoff_mm.tif → stac/Runoff_mm/Runoff_mm.tif
# Copied rasters/Runoff_mm.tif.aux.xml → stac/Runoff_mm.tif.aux/Runoff_mm.tif.aux.xml
# Copied rasters/Slope.tif → stac/Slope/Slope.tif
# Copied rasters/Slope.tif.aux.xml → stac/Slope.tif.aux/Slope.tif.aux.xml
# Copied rasters/Slope_Categories.tif → stac/Slope_Categories/Slope_Categories.tif
# Copied rasters/Slope_Categories.tif.aux.xml → stac/Slope_Categories.tif.aux/Slope_Categories.tif.aux.xml
# Copied rasters/Soils.tif → stac/Soils/Soils.tif
# Copied rasters/Soils.tif.aux.xml → stac/Soils.tif.aux/Soils.tif.aux.xml
# Copied rasters/Soils_test.tif → stac/Soils_test/Soils_test.tif
# Copied rasters/Total_Copper_Concentration.tif → stac/Total_Copper_Concentration/Total_Copper_Concentration.tif
# Copied rasters/Total_Copper_Concentration.tif.aux.xml → stac/Total_Copper_Concentration.tif.aux/Total_Copper_Concentration.tif.aux.xml
# Copied rasters/Total_Kjeldahl_Nitrogen_Concentration.tif → stac/Total_Kjeldahl_Nitrogen_Concentration/Total_Kjeldahl_Nitrogen_Concentration.tif
# Copied rasters/Total_Kjeldahl_Nitrogen_Concentration.tif.aux.xml → stac/Total_Kjeldahl_Nitrogen_Concentration.tif.aux/Total_Kjeldahl_Nitrogen_Concentration.tif.aux.xml
# Copied rasters/Total_Phosphorus_Concentration.tif → stac/Total_Phosphorus_Concentration/Total_Phosphorus_Concentration.tif
# Copied rasters/Total_Phosphorus_Concentration.tif.aux.xml → stac/Total_Phosphorus_Concentration.tif.aux/Total_Phosphorus_Concentration.tif.aux.xml
# Copied rasters/Total_Suspended_Solids_Concentration.tif → stac/Total_Suspended_Solids_Concentration/Total_Suspended_Solids_Concentration.tif
# Copied rasters/Total_Suspended_Solids_Concentration.tif.aux.xml → stac/Total_Suspended_Solids_Concentration.tif.aux/Total_Suspended_Solids_Concentration.tif.aux.xml
# Copied rasters/Total_Zinc_Concentration.tif → stac/Total_Zinc_Concentration/Total_Zinc_Concentration.tif
# Copied rasters/Total_Zinc_Concentration.tif.aux.xml → stac/Total_Zinc_Concentration.tif.aux/Total_Zinc_Concentration.tif.aux.xml
# Copied rasters/Traffic.tif → stac/Traffic/Traffic.tif
# Copied rasters/Traffic.tif.aux.xml → stac/Traffic.tif.aux/Traffic.tif.aux.xml
# Copied rasters/copper_concentration_ug_per_L.tif → stac/copper_concentration_ug_per_L/copper_concentration_ug_per_L.tif
